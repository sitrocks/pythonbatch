# %%
import pandas as pd
df=pd.read_csv("tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
g=df.groupby("Pclass")
g.mean()
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_20948\1668715839.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       1098.224299  0.467290  40.918367  0.476636  0.383178  94.280297
# 2       1117.935484  0.322581  28.777500  0.376344  0.344086  22.202104
# 3       1094.178899  0.330275  24.027945  0.463303  0.417431  12.459678

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.reset()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reset'

# %%
df.set_index("Name",inplace=True)

# %%
df.reset_index()
# Out:
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 412                            Spector, Mr. Woolf    male   NaN      0      0
# 413                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 414                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 415                           Ware, Mr. Frederick    male   NaN      0      0
# 416                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 412           A.5. 3236    8.0500   NaN        S
# 413            PC 17758  108.9000  C105        C
# 414  SOTON/O.Q. 3101262    7.2500   NaN        S
# 415              359309    8.0500   NaN        S
# 416                2668   22.3583   NaN        C
#
# [417 rows x 9 columns]

# %%
d={
    "key1":[1,2,3,4],
    "key2":[5,6,7,8],
    "key3":[9,10,11,12]
}
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     9
# 1     2     6    10
# 2     3     7    11
# 3     4     8    12

# %%
f={
    "key1":[1,2,3,4],
    "key2":[5,6,7,8],
    "key3":[9,10,11,12]
}

# %%
g=df.groupby("Survived")
g

# %%
g.sum()
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_20948\1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           PassengerId  Pclass      Age  SibSp  Parch       Fare
# Survived
# 0              293297     621  6205.91    101     73  7294.8874
# 1              166712     326  3844.59     86     91  7561.6502

# %%
g.mean()
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_20948\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         1102.620301  2.334586  30.272732  0.379699  0.274436  27.527877
# 1         1096.789474  2.144737  30.272362  0.565789  0.598684  49.747699

# %%
g.max()
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_20948\557829741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max()
#         PassengerId  Survived                                           Name  \
# Pclass
# 1              1306         1                      Wilson, Miss. Helen Alice
# 2              1298         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 3              1309         1              van Billiard, Master. Walter John
#
#          Sex   Age  SibSp  Parch       Ticket      Fare Embarked
# Pclass
# 1       male  76.0      3      4  W.E.P. 5734  512.3292        S
# 2       male  63.0      2      3  W./C. 14266   73.5000        S
# 3       male  60.5      8      9   W./C. 6608   69.5500        S

# %%
g.max().transpose()
# Out:
# C:\Users\avnis\AppData\Local\Temp\ipykernel_20948\2848969155.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max().transpose()
# Pclass                               1  \
# PassengerId                       1306
# Survived                             1
# Name         Wilson, Miss. Helen Alice
# Sex                               male
# Age                               76.0
# SibSp                                3
# Parch                                4
# Ticket                     W.E.P. 5734
# Fare                          512.3292
# Embarked                             S
#
# Pclass                                                   2  \
# PassengerId                                           1298
# Survived                                                 1
# Name         del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# Sex                                                   male
# Age                                                   63.0
# SibSp                                                    2
# Parch                                                    3
# Ticket                                         W./C. 14266
# Fare                                                  73.5
# Embarked                                                 S
#
# Pclass                                       3
# PassengerId                               1309
# Survived                                     1
# Name         van Billiard, Master. Walter John
# Sex                                       male
# Age                                       60.5
# SibSp                                        8
# Parch                                        9
# Ticket                              W./C. 6608
# Fare                                     69.55
# Embarked                                     S

# %%
df1=df[["Name","Survived","Pclass"]][0:5]
df2=df[["Name","Survived","Pclass"]][5:10]

# %%
df1
# Out:
#                                            Name  Survived  Pclass
# 0                              Kelly, Mr. James         0       3
# 1              Wilkes, Mrs. James (Ellen Needs)         1       3
# 2                     Myles, Mr. Thomas Francis         0       2
# 3                              Wirz, Mr. Albert         0       3
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)         1       3

# %%
df2
# Out:
#                                         Name  Survived  Pclass
# 5                 Svensson, Mr. Johan Cervin         0       3
# 6                       Connolly, Miss. Kate         1       3
# 7               Caldwell, Mr. Albert Francis         0       2
# 8  Abrahim, Mrs. Joseph (Sophie Halaut Easu)         1       3
# 9                    Davies, Mr. John Samuel         0       3

# %%
pd.concat([df1,df2],axis=1)
# Out:
#                                            Name  Survived  Pclass  \
# 0                              Kelly, Mr. James       0.0     3.0
# 1              Wilkes, Mrs. James (Ellen Needs)       1.0     3.0
# 2                     Myles, Mr. Thomas Francis       0.0     2.0
# 3                              Wirz, Mr. Albert       0.0     3.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       1.0     3.0
# 5                                           NaN       NaN     NaN
# 6                                           NaN       NaN     NaN
# 7                                           NaN       NaN     NaN
# 8                                           NaN       NaN     NaN
# 9                                           NaN       NaN     NaN
#
#                                         Name  Survived  Pclass
# 0                                        NaN       NaN     NaN
# 1                                        NaN       NaN     NaN
# 2                                        NaN       NaN     NaN
# 3                                        NaN       NaN     NaN
# 4                                        NaN       NaN     NaN
# 5                 Svensson, Mr. Johan Cervin       0.0     3.0
# 6                       Connolly, Miss. Kate       1.0     3.0
# 7               Caldwell, Mr. Albert Francis       0.0     2.0
# 8  Abrahim, Mrs. Joseph (Sophie Halaut Easu)       1.0     3.0
# 9                    Davies, Mr. John Samuel       0.0     3.0
